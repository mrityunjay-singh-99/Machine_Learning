# %%
import pandas as pd
import matplotlib.pyplot as plt
processed_df=pd.read_csv(r"C:\Users\Mrityunjay\Data Science Naresh it\Class notes by me\Machaine _learning\model_development\preprocessd_data.csv")
processed_df
# Out:
#       gender       age  no_of_days_subscribed  multi_screen  mail_subscribed  \
# 0          0 -0.264643              -0.946659             0                0
# 1          0  0.029654               1.235009             0                0
# 2          0  2.580235               0.658246             0                0
# 3          0 -1.441834               0.783629             0                1
# 4          0  0.127754               2.288228             0                0
# ...      ...       ...                    ...           ...              ...
# 3401       1 -0.805656               0.479710             0                0
# 3402       0  0.477826               0.674425             0                0
# 3403       0 -0.550521               0.426099             0                1
# 3404       0  0.004651              -0.444637             0                0
# 3405       0 -0.057028               0.317748             0                0
#
# ...

# %% [markdown]
# **Parameter Define**:**Every model have different prameters for developing the model, when we build the model we give some parameter is called hyper parameter.
# using parameter we are builds diffrent value fitted model , it use for prediction. we can set the value of params of the Model and control to predection of it.which our model gets good profermance and avoid complacity.**

# %%
X=processed_df.drop("churn",axis=1)
y=processed_df["churn"]
#======================================================
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)
#=======================================================
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression()
lr_model
#=======================================================
params=lr_model.get_params()
print(params)
#=======================================================
params_grid={'C':[1.0],
             'class_weight':[None],                        
             'dual':[False],
             'fit_intercept':[True],
             'intercept_scaling':[1],
             'l1_ratio':[None],
             'max_iter':[100],
             'multi_class': ['auto'],
             'n_jobs': [None],
             'penalty': ['l2'],
             'random_state': [None],
             'solver': ['lbfgs'],
             'tol': [0.0001],
             'verbose': [0],
             'warm_start': [False]}
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
X=processed_df.drop("churn",axis=1)
y=processed_df["churn"]
#======================================================
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y)
#=======================================================
from sklearn.naive_bayes import GaussianNB
lr_model=GaussianNB()
lr_model
#=======================================================
params=lr_model.get_params()
print(params)
#=======================================================
params_grid={'priors': [None], 'var_smoothing': [1e-09]}
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
X=processed_df.drop("churn",axis=1)
y=processed_df["churn"]
#======================================================
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y)
#=======================================================
from sklearn.neighbors import KNeighborsClassifier
lr_model=KNeighborsClassifier()
lr_model
#=======================================================
params=lr_model.get_params()
print(params)
#=======================================================
params_grid={'algorithm': ['auto'],
             'leaf_size': [30], 
             'metric': ['minkowski'],
             'metric_params': [None], 
             'n_jobs': [None],
             'n_neighbors': [5],
             'p': [2],
             'weights': ['uniform']}
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
X=processed_df.drop("churn",axis=1)
y=processed_df["churn"]
#======================================================
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y)
#=======================================================
from sklearn.tree import DecisionTreeClassifier
lr_model=DecisionTreeClassifier()
lr_model
#=======================================================
params=lr_model.get_params()
print(params)
#=======================================================
params_grid={'ccp_alpha': [0.0],
             'class_weight': [None],
             'criterion': ['gini'], 
             'max_depth': [None],
             'max_features': [None],
             'max_leaf_nodes': [None],
             'min_impurity_decrease': [0.0],
             'min_samples_leaf': [1],
             'min_samples_split': [2],
             'min_weight_fraction_leaf': [0.0],
             'monotonic_cst': [None],
             'random_state': [None],
             'splitter': ['best']}
# Out:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': None, 'splitter': 'best'}

# %%
X=processed_df.drop("churn",axis=1)
y=processed_df["churn"]
#======================================================
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y)
#=======================================================
from sklearn.ensemble import RandomForestClassifier
lr_model=RandomForestClassifier()
lr_model
#=======================================================
params=lr_model.get_params()
print(params)
#=======================================================
params_grid={'bootstrap': [True],
             'ccp_alpha': [0.0],
             'class_weight': [None],
             'criterion': ['gini'],
             'max_depth': [None], 
             'max_features': ['sqrt'],
             'max_leaf_nodes': [None], 
             'max_samples': [None],
             'min_impurity_decrease': [0.0],
             'min_samples_leaf': [1],
             'min_samples_split': [2],
             'min_weight_fraction_leaf': [0.0],
             'monotonic_cst': [None],
             'n_estimators': [100],
             'n_jobs': [None],
             'oob_score': [False],
             'random_state': [None],
             'verbose': [0],
             'warm_start': [False]}
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
